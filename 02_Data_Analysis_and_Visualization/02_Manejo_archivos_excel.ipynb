# %% [markdown]
# # Using Excel File

# %%
# The same that CSV File, just only change from CSV to Excel, but it's the same process

# %%
import pandas as pd
import openpyxl

df = pd.read_excel('Archivos_CSV/reporte_solicitudes_2025-12-12.xlsx')
df.head()
# Out:
#    Unnamed: 0 tipo_identificacion identificacion       sexo  \
# 0           0                  CC       52308919   Femenino
# 1           1                  TI     1121879650   Femenino
# 2           2                  CC       79249004  Masculino
# 3           3                  CC       35323713   Femenino
# 4           4                  CC       20337008   Femenino
#
#                      nombre_paciente fecha_nacimiento  edad tipo_edad  \
# 0  YALDY LILIANA RODRIGUEZ HERNANDEZ       1975-09-21  48.0         A
# 1           MILEY SOFIA TORRES LOPEZ       2009-07-16  14.0         A
# 2       NESTOR FREDY SANDOVAL MORENO       1971-07-06  51.0         A
# 3           ESPERANZA SOPO CASTAÑEDA       1957-01-04  65.0         A
# 4      MARIA CAROLINA CHAVES HERRERA       1942-07-24  81.0         A
#
#    estancia_id    estado  ...                             servicio  \
# 0         7470  Egresado  ...     Cuidado basico adultos - 4 Camas
# ...

# %%
# Information about the File
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82954 entries, 0 to 82953
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            82954 non-null  int64
#  1   tipo_identificacion   82954 non-null  object
#  2   identificacion        82954 non-null  object
#  3   sexo                  82954 non-null  object
#  4   nombre_paciente       82954 non-null  object
#  5   fecha_nacimiento      82954 non-null  datetime64[ns]
#  6   edad                  82948 non-null  float64
#  7   tipo_edad             82948 non-null  object
#  8   estancia_id           82954 non-null  int64
#  9   estado                82954 non-null  object
#  10  fecha_ingreso         82954 non-null  datetime64[ns]
#  11  fecha_egreso          82469 non-null  datetime64[ns]
#  12  ips                   82954 non-null  object
#  13  dx_actual             82954 non-null  object
# ...

# %%
# Instantiating describe() the Excel File:
df.describe()
# Out:
#          Unnamed: 0               fecha_nacimiento          edad  \
# count  82954.000000                          82954  82948.000000
# mean   41476.500000  1979-04-05 11:18:02.595173248     45.585861
# min        0.000000            1910-01-05 00:00:00     -4.000000
# 25%    20738.250000            1954-04-25 00:00:00     19.000000
# 50%    41476.500000            1974-06-24 00:00:00     50.000000
# 75%    62214.750000            2005-12-17 18:00:00     70.000000
# max    82953.000000            2025-12-10 00:00:00    113.000000
# std    23946.901452                            NaN     29.055408
#
#          estancia_id                  fecha_ingreso  \
# count   82954.000000                          82954
# mean   313412.103142  2024-08-29 19:31:31.525423872
# min       993.000000            2009-02-24 00:00:00
# 25%    188830.500000            2024-01-26 00:00:00
# 50%    322797.500000            2024-09-17 00:00:00
# 75%    449544.250000            2025-05-09 00:00:00
# ...
