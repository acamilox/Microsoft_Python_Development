# %% [markdown]
# # Diccionarios y Listas en Notebboks

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'Linda'],
        'Age': [25, 30, 28, 32]
        }

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28
# 3    Linda   32

# %%
data = [['Alice', 25], ['Bob', 30], ['Charlie', 28]]

df = pd.DataFrame(data, columns=['Name', 'Age'])
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28

# %%
# Reading a CSV file into a DataFrame
df = pd.read_csv('data.csv')
print(df)

# %%
# using df.tail()
df.tail()
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28

# %% [markdown]
# Applying filters

# %%
# Select age
df['Age']
# Out:
# 0    25
# 1    30
# 2    28
# Name: Age, dtype: int64

# %%
# Selection of columns
df[['Name', 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28

# %%
df.iloc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
# Filter rows where 'Age' is greater than 25
df[df['Age'] > 25]
# Out:
#       Name  Age
# 1      Bob   30
# 2  Charlie   28

# %%
# Filter null values
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False
# 2  False  False
