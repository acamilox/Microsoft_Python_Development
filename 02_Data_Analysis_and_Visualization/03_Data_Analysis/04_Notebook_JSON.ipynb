# %% [markdown]
# # Using JSON FILE

# %%
import json

# Cargar el archivo JSON
with open('Archivos_CSV_Excel_y_JSON/04_example.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
print(data)
# Out:
# {'empleados': [{'id': 1, 'nombre': 'Ana García', 'edad': 28, 'departamento': 'Ventas', 'salario': 45000, 'fecha_contratacion': '2021-03-15', 'habilidades': ['comunicación', 'negociación', 'CRM'], 'activo': True}, {'id': 2, 'nombre': 'Carlos López', 'edad': 35, 'departamento': 'IT', 'salario': 62000, 'fecha_contratacion': '2019-07-22', 'habilidades': ['Python', 'SQL', 'AWS', 'Docker'], 'activo': True}, {'id': 3, 'nombre': 'María Rodríguez', 'edad': 42, 'departamento': 'RRHH', 'salario': 52000, 'fecha_contratacion': '2018-11-30', 'habilidades': ['reclutamiento', 'capacitación', 'ley laboral'], 'activo': True}, {'id': 4, 'nombre': 'Juan Martínez', 'edad': 31, 'departamento': 'Ventas', 'salario': 48000, 'fecha_contratacion': '2020-05-10', 'habilidades': ['gestión de cuentas', 'análisis de mercado'], 'activo': False}, {'id': 5, 'nombre': 'Laura Fernández', 'edad': 29, 'departamento': 'Marketing', 'salario': 51000, 'fecha_contratacion': '2022-01-18', 'habilidades': ['redes sociales', 'SEO'
# ...
